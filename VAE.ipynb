# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cpu")

# %%
device
# Out:
# device(type='cpu')

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters


def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('data/%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split(',')] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
MAX_LENGTH = 500
eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s ",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)


def filterPair(p):
    try:
        
        return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH and \
        p[1].startswith(eng_prefixes)
    except:
        pass


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
def prepareData(lang1, lang2, reverse=False):    
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


input_lang, output_lang, pairs = prepareData('two', 'two', True)
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 43056 sentence pairs
# Trimmed to 326 sentence pairs
# Counting words...
# Counted words:
# two 865
# two 823
# ['i am bringing gifts unto men .', 'i am bringing gifts unto men .']

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('real: ', pair[0])
        #print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('prediction: ', output_sentence)
        print('')

# %%
hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = DecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

trainIters(encoder1, attn_decoder1, 100000, print_every=1000)
# Out:
# 0m 41s (- 68m 39s) (1000 1%) 3.4869
# 1m 20s (- 65m 26s) (2000 2%) 2.9569
# 1m 59s (- 64m 30s) (3000 3%) 2.6178
# 2m 38s (- 63m 25s) (4000 4%) 2.2285
# 3m 18s (- 62m 49s) (5000 5%) 1.8447
# 3m 58s (- 62m 21s) (6000 6%) 1.3226
# 4m 42s (- 62m 36s) (7000 7%) 0.9249
# 5m 24s (- 62m 8s) (8000 8%) 0.5418
# 6m 7s (- 61m 53s) (9000 9%) 0.2896
# 6m 47s (- 61m 11s) (10000 10%) 0.1595
# 7m 30s (- 60m 45s) (11000 11%) 0.0877
# 8m 10s (- 59m 57s) (12000 12%) 0.0535
# 8m 53s (- 59m 27s) (13000 13%) 0.0438
# 9m 34s (- 58m 51s) (14000 14%) 0.0324
# 10m 15s (- 58m 5s) (15000 15%) 0.0274
# 10m 55s (- 57m 22s) (16000 16%) 0.0231
# 11m 36s (- 56m 42s) (17000 17%) 0.0198
# 12m 22s (- 56m 22s) (18000 18%) 0.0177
# 13m 5s (- 55m 48s) (19000 19%) 0.0158
# 13m 49s (- 55m 16s) (20000 20%) 0.0143
# 14m 30s (- 54m 32s) (21000 21%) 0.0130
# 15m 10s (- 53m 47s) (22000 22%) 0.0122
# 15m 52s (- 53m 8s) (23000 23%) 0.0110
# 16m 36s (- 52m 36s) (24000 24%) 0.0103
# 17m 19s (- 51m 59s) (25000 25%) 0.0097
# 18m 3s (- 51m 22s) (26000 26%) 0.0091
# 18m 45s (- 50m 44s) (27000 27%) 0.0085
# 19m 29s (- 50m 8s) (28000 28%) 0.0082
# 20m 12s (- 49m 27s) (29000 28%) 0.0077
# 20m 56s (- 48m 51s) (30000 30%) 0.0074
# 21m 37s (- 48m 9s) (31000 31%) 0.0070
# 22m 18s (- 47m 25s) (32000 32%) 0.0065
# 22m 59s (- 46m 41s) (33000 33%) 0.0064
# 23m 43s (- 46m 3s) (34000 34%) 0.0061
# 24m 28s (- 45m 27s) (35000 35%) 0.0058
# 25m 13s (- 44m 50s) (36000 36%) 0.0056
# 25m 58s (- 44m 13s) (37000 37%) 0.0054
# 26m 43s (- 43m 35s) (38000 38%) 0.0051
# 27m 27s (- 42m 57s) (39000 39%) 0.0050
# 28m 11s (- 42m 17s) (40000 40%) 0.0048
# 28m 58s (- 41m 41s) (41000 41%) 0.0048
# 29m 43s (- 41m 2s) (42000 42%) 0.0046
# 30m 28s (- 40m 24s) (43000 43%) 0.0044
# 31m 13s (- 39m 43s) (44000 44%) 0.0043
# 31m 57s (- 39m 3s) (45000 45%) 0.0041
# 32m 42s (- 38m 23s) (46000 46%) 0.0041
# 33m 26s (- 37m 42s) (47000 47%) 0.0039
# 34m 7s (- 36m 58s) (48000 48%) 0.0038
# 34m 53s (- 36m 18s) (49000 49%) 0.0038
# 35m 34s (- 35m 34s) (50000 50%) 0.0036
# 36m 13s (- 34m 48s) (51000 51%) 0.0036
# 36m 52s (- 34m 1s) (52000 52%) 0.0034
# 37m 31s (- 33m 16s) (53000 53%) 0.0034
# 38m 10s (- 32m 30s) (54000 54%) 0.0033
# 38m 49s (- 31m 45s) (55000 55%) 0.0032
# 39m 28s (- 31m 0s) (56000 56%) 0.0031
# 40m 6s (- 30m 15s) (57000 56%) 0.0031
# 40m 45s (- 29m 30s) (58000 57%) 0.0031
# 41m 23s (- 28m 46s) (59000 59%) 0.0029
# 42m 2s (- 28m 1s) (60000 60%) 0.0029
# 42m 40s (- 27m 17s) (61000 61%) 0.0028
# 43m 19s (- 26m 33s) (62000 62%) 0.0027
# 43m 59s (- 25m 50s) (63000 63%) 0.0027
# 44m 43s (- 25m 9s) (64000 64%) 0.0027
# 45m 27s (- 24m 28s) (65000 65%) 0.0026
# 46m 13s (- 23m 48s) (66000 66%) 0.0026
# 46m 58s (- 23m 8s) (67000 67%) 0.0025
# 47m 44s (- 22m 27s) (68000 68%) 0.0025
# 48m 29s (- 21m 47s) (69000 69%) 0.0024
# 49m 14s (- 21m 6s) (70000 70%) 0.0024
# 49m 59s (- 20m 25s) (71000 71%) 0.0023
# 50m 44s (- 19m 44s) (72000 72%) 0.0023
# 51m 30s (- 19m 3s) (73000 73%) 0.0023
# 52m 18s (- 18m 22s) (74000 74%) 0.0022
# 53m 14s (- 17m 44s) (75000 75%) 0.0022
# 54m 10s (- 17m 6s) (76000 76%) 0.0022
# 55m 1s (- 16m 26s) (77000 77%) 0.0021
# 55m 46s (- 15m 44s) (78000 78%) 0.0021
# 56m 32s (- 15m 1s) (79000 79%) 0.0021
# 57m 17s (- 14m 19s) (80000 80%) 0.0020
# 58m 3s (- 13m 37s) (81000 81%) 0.0020
# 58m 47s (- 12m 54s) (82000 82%) 0.0020
# 59m 32s (- 12m 11s) (83000 83%) 0.0020
# 60m 19s (- 11m 29s) (84000 84%) 0.0019
# 61m 3s (- 10m 46s) (85000 85%) 0.0019
# 61m 50s (- 10m 3s) (86000 86%) 0.0019
# 62m 36s (- 9m 21s) (87000 87%) 0.0019
# 63m 24s (- 8m 38s) (88000 88%) 0.0018
# 64m 10s (- 7m 55s) (89000 89%) 0.0018
# 64m 57s (- 7m 13s) (90000 90%) 0.0018
# 65m 42s (- 6m 29s) (91000 91%) 0.0018
# 66m 29s (- 5m 46s) (92000 92%) 0.0017
# 67m 14s (- 5m 3s) (93000 93%) 0.0017
# 68m 1s (- 4m 20s) (94000 94%) 0.0017
# 68m 47s (- 3m 37s) (95000 95%) 0.0017
# 69m 33s (- 2m 53s) (96000 96%) 0.0016
# 70m 20s (- 2m 10s) (97000 97%) 0.0016
# 71m 6s (- 1m 27s) (98000 98%) 0.0016
# 71m 51s (- 0m 43s) (99000 99%) 0.0016
# 72m 37s (- 0m 0s) (100000 100%) 0.0016

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# real:  we are both of us genuine neerdowells and neerdoills .
# prediction:  we are both of us genuine neerdowells and neerdoills . <EOS>
#
# real:
# prediction:  i am gifted with a sense of cleanliness the keenness of which is phenomenal so much so <EOS>
#
# real:  to be rid of themselves for a moment . . .
# prediction:  they are thus able to forget themselves <EOS>
#
# real:  i am zarathustra the godless where do i find mine equal ?
# prediction:  i am zarathustra the godless where do i find mine equal ? <EOS>
#
# real:  i am not active any longer .
# prediction:  i am not active any longer . <EOS>
#
# real:  you are so brave and quiet
# prediction:  you are so brave and quiet <EOS>
#
# real:  they arewhat name for those ?friends
# prediction:  they arewhat name for those ?friends <EOS>
#
# real:  he is a lucky man .
# prediction:  he is a lucky man . <EOS>
#
# real:  he is bad in his general human capacity and he soothes himself a little with the assertion that we are all alike .
# prediction:  he is bad in his general human capacity and he soothes himself a little with the assertion that we are all alike . <EOS>
#
# real:  i am going to stay here a while .
# prediction:  i am going to stay here a while . <EOS>

# %%
output_words, attentions = evaluate(
    encoder1, attn_decoder1, "patriot beautiful and kind")
plt.matshow(attentions.numpy())

# %%
output_sentence = ' '.join(output_words)
print('prediction: ', output_sentence)
# Out:
# prediction:  she is and sweeter . <EOS>

# %%
def showAttention(input_sentence, output_words, attentions):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()


def evaluateAndShowAttention(input_sentence):
    output_words, attentions = evaluate(
        encoder1, attn_decoder1, input_sentence)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions)


evaluateAndShowAttention("is  milan too beautiful .")

evaluateAndShowAttention("she is going to die")
# Out:
# input = is  milan too beautiful .
# output = she is sound very beautiful . <EOS>
# input = she is going to die
# output = she is going to die <EOS>
# /home/julia/anaconda3/envs/tesis/lib/python3.6/site-packages/ipykernel_launcher.py:17: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
pairs
# Out:
# [['i am always in love .', 'i am always in love .'],
#  ['you are a frozen faced . . . wop .', 'you are a frozen faced . . . wop .'],
#  ['they are expecting him at any moment',
#   'they are expecting him at any moment'],
#  ['i am a professional gambler', 'i am a professional gambler'],
#  ['i am not really .', 'i am not really .'],
#  ['i am sure he would and more since he is young and strong .',
#   'i am sure he would and more since he is young and strong .'],
#  ['he is a cardplayer .', 'he is a cardplayer .'],
#  ['he is treating himself for it .', 'he is treating himself for it .'],
#  ['they are going to come in .', 'they are going to come in .'],
#  ['he is rather a waste of time .', 'he is rather a waste of time .'],
#  ['they arent girls they are old war comrades .',
#   'they arent girls they are old war comrades .'],
#  ['we are robbing you .', 'we are robbing you .'],
#  ['he is a little delirious .', 'he is a little delirious .'],
#  ['i am a strange old man .', 'i am a strange old man .'],
#  ['you are too young .', 'you are too young .'],
#  ['they are shelling quite a little still',
#   'they are shelling quite a little still'],
#  ['they are all different and they fly in different ways but the sensation is the same and the last one is as good as the first .',
#   'they are all different and they fly in different ways but the sensation is the same and the last one is as good as the first .'],
#  ['we are devotees of the pictorial arts .',
#   'we are devotees of the pictorial arts .'],
#  ['you are a philosopher .', 'you are a philosopher .'],
#  ['they are a younger nation .', 'they are a younger nation .'],
#  ['you are making the discovery .', 'you are making the discovery .'],
#  ['i am sorry you are not a member .', 'i am sorry you are not a member .'],
#  ['you are the first patient .', 'you are the first patient .'],
#  ['you are nice when you are gentle .', 'you are nice when you are gentle .'],
#  ['he is a good friend of mine .', 'he is a good friend of mine .'],
#  ['i am quite sure .', 'i am quite sure .'],
#  ['you are in such a hurry to get back to the front ?',
#   'you are in such a hurry to get back to the front ?'],
#  ['i am a very reliable interpreter .', 'i am a very reliable interpreter .'],
#  ['he is very thoughtful for us .', 'he is very thoughtful for us .'],
#  ['you are already a man .', 'you are already a man .'],
#  ['you are not a human being .', 'you are not a human being .'],
#  ['they are waiting for me .', 'they are waiting for me .'],
#  ['you are a dear .', 'you are a dear .'],
#  ['you are of the great translators .', 'you are of the great translators .'],
#  ['she is gone to stresa .', 'she is gone to stresa .'],
#  ['they are so big and lovely .', 'they are so big and lovely .'],
#  ['i am off for harrys .', 'i am off for harrys .'],
#  ['he thought . ',
#   'i am opposed to the excessive butcher bill',
#   ' christ',
#   'he thought . ',
#   'i am opposed to the excessive butcher bill',
#   ' christ'],
#  ['she is of very good family .', 'she is of very good family .'],
#  ['i am still an old man .', 'i am still an old man .'],
#  ['i am an only child', 'i am an only child'],
#  ['you are a lucky girl if you can write truly what you hear or think .',
#   'you are a lucky girl if you can write truly what you hear or think .'],
#  ['i am sorry they did not fly better .',
#   'i am sorry they did not fly better .'],
#  ['he is an ass .', 'he is an ass .'],
#  ['i am very deeply moved by the portrait and i am not entirely responsible for what i say .',
#   'i am very deeply moved by the portrait and i am not entirely responsible for what i say .'],
#  ['you are really an italian .', 'you are really an italian .'],
#  ['i am a bull fighter .', 'i am a bull fighter .'],
#  ['i am not at the front .', 'i am not at the front .'],
#  ['you are quite correct .', 'you are quite correct .'],
#  ['i am too old to club sharks to death .',
#   'i am too old to club sharks to death .'],
#  ['you are sure of this ?', 'you are sure of this ?'],
#  ['we are both wounded a little .', 'we are both wounded a little .'],
#  ['he is silent these days .', 'he is silent these days .'],
#  ['i am completely without luck .', 'i am completely without luck .'],
#  ['i am so sorry .', 'i am so sorry .'],
#  ['we are war brothers .', 'we are war brothers .'],
#  ['you are purer and sweeter .', 'you are purer and sweeter .'],
#  ['i am so sorry to be late .', 'i am so sorry to be late .'],
#  ['she is sound and not harmed in any way except for the tiller .',
#   'she is sound and not harmed in any way except for the tiller .'],
#  ['i am the victim of illusions .', 'i am the victim of illusions .'],
#  ['i am not lucky .', 'i am not lucky .'],
#  ['i am a writer .', 'i am a writer .'],
#  ['i am going to stay here a while .', 'i am going to stay here a while .'],
#  ['i am not an inquisitor or whatever the female of inquisitor is .',
#   'i am not an inquisitor or whatever the female of inquisitor is .'],
#  ['i am not really a good bull fighter .',
#   'i am not really a good bull fighter .'],
#  ['and she is as gay as a girl and does not have any fear of dying . ',
#   'she is over eighty',
#   'but thought',
#   ' he did not say',
#   'and she is as gay as a girl and does not have any fear of dying . ',
#   'she is over eighty',
#   'but thought',
#   ' he did not say'],
#  ['i am afraid of him in the night sometimes .',
#   'i am afraid of him in the night sometimes .'],
#  ['they are down now to gamble at the lido .',
#   'they are down now to gamble at the lido .'],
#  ['i am not lucky anymore .', 'i am not lucky anymore .'],
#  ['you are so modest .', 'you are so modest .'],
#  ['i am sorry that i went too far out .',
#   'i am sorry that i went too far out .'],
#  ['you arent going to die .', 'you arent going to die .'],
#  ['you are so brave and quiet', 'you are so brave and quiet'],
#  ['i am all right with the leg or not .',
#   'i am all right with the leg or not .'],
#  ['i am a poor idealist .', 'i am a poor idealist .'],
#  ['you arent funny .', 'you arent funny .'],
#  ['they are going to arrest you in the morning .',
#   'they are going to arrest you in the morning .'],
#  ['you are a fine boy .', 'you are a fine boy .'],
#  ['i am not a morning drinker', 'i am not a morning drinker'],
#  ['we are married privately .', 'we are married privately .'],
#  ['he is a surgeon of the ospedale maggiore .',
#   'he is a surgeon of the ospedale maggiore .'],
#  ['he is too concentrated .', 'he is too concentrated .'],
#  ['i am not joking .', 'i am not joking .'],
#  ['i am all right .', 'i am all right .'],
#  ['he is my brother .', 'he is my brother .'],
#  ['they are wide spread and the flying fish have little chance .',
#   'they are wide spread and the flying fish have little chance .'],
#  ['you are a patriot .', 'you are a patriot .'],
#  ['you are also damn sagacious .', 'you are also damn sagacious .'],
#  ['they are good books but can be dull if you have been there .',
#   'they are good books but can be dull if you have been there .'],
#  ['he is a lucky man .', 'he is a lucky man .'],
#  ['he is not the villain .', 'he is not the villain .'],
#  ['he is almost blind .', 'he is almost blind .'],
#  ['she is kind and very beautiful .', 'she is kind and very beautiful .'],
#  ['you are two years younger than the girl that you portray and she is younger and older than hell which is quite an old place .',
#   'you are two years younger than the girl that you portray and she is younger and older than hell which is quite an old place .'],
#  ['i am glad we do not have to try to kill the stars .',
#   'i am glad we do not have to try to kill the stars .'],
#  ['they are a damn sight more important when you put them on paper .',
#   'they are a damn sight more important when you put them on paper .'],
#  ['they are worth nothing .', 'they are worth nothing .'],
#  ['they are not at the hotel .', 'they are not at the hotel .'],
#  ['we are smoking the enemy with artillery and mortar .',
#   'we are smoking the enemy with artillery and mortar .'],
#  ['they are what we have instead of the locusts this year .',
#   'they are what we have instead of the locusts this year .'],
#  ['i am and signed her name .', 'i am and signed her name .'],
#  ['i am very tired of this war .', 'i am very tired of this war .'],
#  ['she is going to milan too .', 'she is going to milan too .'],
#  ['i am as clear as the stars that are my brothers .',
#   'i am as clear as the stars that are my brothers .'],
#  ['i am all confidence .', 'i am all confidence .'],
#  ['i am very sorry .', 'i am very sorry .'],
#  ['you are welcome of course to another opinion .',
#   'you are welcome of course to another opinion .'],
#  ['you are better with her without me .',
#   'you are better with her without me .'],
#  ['i am a boy and i must obey him .', 'i am a boy and i must obey him .'],
#  ['you are a foreigner .', 'you are a foreigner .'],
#  ['they are keeping them for the pleasure of dugout hiders in the rear .',
#   'they are keeping them for the pleasure of dugout hiders in the rear .'],
#  ['you are much richer than i am .', 'you are much richer than i am .'],
#  ['i am sure there is plenty of food .',
#   'i am sure there is plenty of food .'],
#  ['she is all right .', 'she is all right .'],
#  ['she said . ',
#   'you are slow on the up take',
#   ' i say',
#   'she said . ',
#   'you are slow on the up take',
#   ' i say'],
#  ['he is an excellent surgeon and i would rather have his judgment than any surgeon i know .',
#   'he is an excellent surgeon and i would rather have his judgment than any surgeon i know .'],
#  ['you arent going to die .', 'you arent going to die .'],
#  ['you are probably wiser than i am .', 'you are probably wiser than i am .'],
#  ['he is beautiful and noble and knows no fear of anything .',
#   'he is beautiful and noble and knows no fear of anything .'],
#  ['you are sure you dont want more ?', 'you are sure you dont want more ?'],
#  ['he is not a scavenger nor just a moving appetite as some sharks are .',
#   'he is not a scavenger nor just a moving appetite as some sharks are .'],
#  ['i am very dull and i am sorry .', 'i am very dull and i am sorry .'],
#  ['we are not peasants .', 'we are not peasants .'],
#  ['he is only nineteen .', 'he is only nineteen .'],
#  ['she is the only lady ihave ever known who was as charming when she was drunk as when she wassober .',
#   'she is the only lady ihave ever known who was as charming when she was drunk as when she wassober .'],
#  ['i am sure his loss was a blow to science as well as to his family .',
#   'i am sure his loss was a blow to science as well as to his family .'],
#  ['you are very comfortable here .', 'you are very comfortable here .'],
#  ['you are not a bandit and this has nothing to do with the cinema .',
#   'you are not a bandit and this has nothing to do with the cinema .'],
#  ['you are talking about spezia .', 'you are talking about spezia .'],
#  ['i am an italian .', 'i am an italian .'],
#  ['he is much fish still and i saw that the hook was in the corner of his mouth and he has kept his mouth tight shut .',
#   'he is much fish still and i saw that the hook was in the corner of his mouth and he has kept his mouth tight shut .'],
#  ['you are an ignorant foul mouthed dago .',
#   'you are an ignorant foul mouthed dago .'],
#  ['i am a simple girl .', 'i am a simple girl .'],
#  ['she is a fine woman of great intelligence and sympathy .',
#   'she is a fine woman of great intelligence and sympathy .'],
#  ['we are having it again and without sorrow .',
#   'we are having it again and without sorrow .'],
#  ['you are still gran maestro and the condottieri .',
#   'you are still gran maestro and the condottieri .'],
#  ['she is pleased because you take bananas .',
#   'she is pleased because you take bananas .'],
#  ['you are a noble young man .', 'you are a noble young man .'],
#  ['i am not active any longer .', 'i am not active any longer .'],
#  ['i am only better than him through trickery and he meant me no harm .',
#   'i am only better than him through trickery and he meant me no harm .'],
#  ['we are tourists and we want to do the winter sport .',
#   'we are tourists and we want to do the winter sport .'],
#  ['you are a foreigner .', 'you are a foreigner .'],
#  ['they are training an army of ten million .',
#   'they are training an army of ten million .'],
#  ['i am the snake of reason .', 'i am the snake of reason .'],
#  ['they are really interchangeable .', 'they are really interchangeable .'],
#  ['they are like that .', 'they are like that .'],
#  ['you are not that kind of a soldier', 'you are not that kind of a soldier'],
#  ['i am now in love with miss barkley .',
#   'i am now in love with miss barkley .'],
#  ['we are born with all we have and we never learn .',
#   'we are born with all we have and we never learn .'],
#  ['i am very sorry to have stayed so long .',
#   'i am very sorry to have stayed so long .'],
#  ['we are all splendid .', 'we are all splendid .'],
#  ['i am supposed to move around and let them see the uniform .',
#   'i am supposed to move around and let them see the uniform .'],
#  ['he is in much pain .', 'he is in much pain .'],
#  ['i am your friend .', 'i am your friend .'],
#  ['he is here at the hospital .', 'he is here at the hospital .'],
#  ['i am positive you will get the silver .',
#   'i am positive you will get the silver .'],
#  ['para said . ',
#   'i am commanding the battalion',
#   ' you see',
#   'para said . ',
#   'i am commanding the battalion',
#   ' you see'],
#  ['you are not even an italian .', 'you are not even an italian .'],
#  ['you are mr . henry ?', 'you are mr . henry ?'],
#  ['as i have been so many times . ',
#   'i am wrong',
#   'probably',
#   ' though',
#   'as i have been so many times . ',
#   'i am wrong',
#   'probably',
#   ' though'],
#  ['i am in no trouble .', 'i am in no trouble .'],
#  ['you arent in switzerland until you come to brissago .',
#   'you arent in switzerland until you come to brissago .'],
#  ['you are under seventeen .', 'you are under seventeen .'],
#  ['i am the snake .', 'i am the snake .'],
#  ['i am your lovely .', 'i am your lovely .'],
#  ['she is very well .', 'she is very well .'],
#  ['he is a priest he will appreciate it .',
#   'he is a priest he will appreciate it .'],
#  ['they are very big and young .', 'they are very big and young .'],
#  ['you are beside yourself .', 'you are beside yourself .'],
#  ['you are no longer of any real use to the army of the united states .',
#   'you are no longer of any real use to the army of the united states .'],
#  ['they are apt to for a time .', 'they are apt to for a time .'],
#  ['we are brothers and we love each other .',
#   'we are brothers and we love each other .'],
#  ['i am sure he had never been in love in his life .',
#   'i am sure he had never been in love in his life .'],
#  ['you are not going to die .', 'you are not going to die .'],
#  ['i am only the unknown country .', 'i am only the unknown country .'],
#  ['he is a very excellent surgeon of milan .',
#   'he is a very excellent surgeon of milan .'],
#  ['he is well taken care of .', 'he is well taken care of .'],
#  ['i am just more affectionate .', 'i am just more affectionate .'],
#  ['i am tired from thinking so much .', 'i am tired from thinking so much .'],
#  ['i am not good for many more turns .',
#   'i am not good for many more turns .'],
#  ['they are the best soldiers .', 'they are the best soldiers .'],
#  ['they are our potential enemy .', 'they are our potential enemy .'],
#  ['i am quite sure it was worse .', 'i am quite sure it was worse .'],
#  ['i am over bold .', 'i am over bold .'],
#  ['you are in love with this girl now ?',
#   'you are in love with this girl now ?'],
#  ['i am very moved to see you badly wounded .',
#   'i am very moved to see you badly wounded .'],
#  ['he is the legitimate son of president wilson .',
#   'he is the legitimate son of president wilson .'],
#  ['we are friends of he who wounded him .',
#   'we are friends of he who wounded him .'],
#  ['he is the sort of person they want as a member .',
#   'he is the sort of person they want as a member .'],
#  ['i am an officer .', 'i am an officer .'],
#  ['they are bored in this town .', 'they are bored in this town .'],
#  ['they are too stupid .', 'they are too stupid .'],
#  ['i am very truly sorry .', 'i am very truly sorry .'],
#  ['you are different though .', 'you are different though .'],
#  ['we are governed by what you find in the bottom of dead beer glasses that whores have dunked their cigarettes in .',
#   'we are governed by what you find in the bottom of dead beer glasses that whores have dunked their cigarettes in .'],
#  ['he is rather hard .', 'he is rather hard .'],
#  ['you are asking for the army or as my physician ?',
#   'you are asking for the army or as my physician ?'],
#  ['we are in our home', 'we are in our home'],
#  ['i am on leave .', 'i am on leave .'],
#  ['they are all without law to protect them .',
#   'they are all without law to protect them .'],
#  ['i am sure you would like it here very much at locarno .',
#   'i am sure you would like it here very much at locarno .'],
#  ['they are what is really distinguished .',
#   'they are what is really distinguished .'],
#  ['you are very well liked in this city .',
#   'you are very well liked in this city .'],
#  ['he is one of the officers of the society .',
#   'he is one of the officers of the society .'],
#  ['i am perfectly happy .', 'i am perfectly happy .'],
#  ['i am a little tired too .', 'i am a little tired too .'],
#  ['they are working from there .', 'they are working from there .'],
#  ['they are moving out too fast and too far .',
#   'they are moving out too fast and too far .'],
#  ['you are very good to say so .', 'you are very good to say so .'],
#  ['you are a south american ?', 'you are a south american ?'],
#  ['they are mostly different .', 'they are mostly different .'],
#  ['you are my great and good friend and financial protector .',
#   'you are my great and good friend and financial protector .'],
#  ['they are our brothers like the flying fish .',
#   'they are our brothers like the flying fish .'],
#  ['i am not in trouble .', 'i am not in trouble .'],
#  ['i am a humane man .', 'i am a humane man .']]
